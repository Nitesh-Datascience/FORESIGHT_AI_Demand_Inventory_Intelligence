# %% [markdown]
# # FORESIGHT — Model & Backtest
#
# Run `python run_pipeline.py` first.

# %%
from pathlib import Path
import pandas as pd
ROOT=Path('..')
print('Open artifacts/ for generated results.')
